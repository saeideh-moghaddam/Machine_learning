# %%
import numpy as np
import random
import numpy as np
from mpl_toolkits.mplot3d import Axes3D
import matplotlib.pyplot as plt
n= 250

melons_width = np.random.normal(12, 8, n) 
melons_height = np.random.normal(8, 2, n)
melons_weight = np.random.normal(10, 0.5, n)
dict_melon = {'wid':melons_width, 'hei':melons_height, 'wei':melons_weight}

balloon_width = np.random.normal(25, 4, n)
balloon_height = np.random.normal(15, 7, n)
balloon_weight = np.random.normal(0.5, 0.2, n)
dict_balloon = {'wid':balloon_width, 'hei':balloon_height, 'wei':balloon_weight}

ax = plt.axes(projection='3d')
ax.scatter(dict_melon['wid'], dict_melon['hei'], dict_melon['wei'],marker='^', c='orange', label='Melons')

ax.scatter(dict_balloon['wid'], dict_balloon['hei'], dict_balloon['wei'], c='Blue', label='Ballons')

ax.legend()

ax.set_xlabel('Width')
ax.set_ylabel('Length')
ax.set_zlabel('Weight')

plt.show()
